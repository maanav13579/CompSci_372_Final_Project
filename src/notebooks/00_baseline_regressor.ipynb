# %%
#script for running baseline regressor
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys, os
PROJECT_ROOT = '/content/drive/MyDrive/Duke Undergrad/Senior/Applied Machine Learning/Final Project'
sys.path.insert(0, os.path.join(PROJECT_ROOT, 'src'))
os.chdir(PROJECT_ROOT)

# %%
# !pip install -q torch torchvision timm grad-cam tensorboard tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 75.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for grad-cam (pyproject.toml) ... done

# %%
#Run baseline regressor training and comparison script
# %cd "/content/drive/MyDrive/Duke Undergrad/Senior/Applied Machine Learning/Final Project"

# !PYTHONPATH=src python src/baseline_regressor.py \
    --data_root data/nutrition5k \
    --model_path artifacts/models/regressor_best.pth
# Out:
# /content
# Using device: cuda
# Loading data...
# Loaded 4059 train IDs and 709 test IDs from split files
# Loading metadata from: data/nutrition5k/metadata/dish_metadata_cafe1.csv
# Loaded 4768 rows from metadata
# Using columns: dish_id='dish_id', calories='total_calories'
# Loaded 4766 dishes with valid calorie data
# Loading images from: data/nutrition5k/imagery/realsense_overhead
# Found 2754 valid samples, skipped 1305
# Split 'train': 2479 samples
# Loaded 4059 train IDs and 709 test IDs from split files
# Loading metadata from: data/nutrition5k/metadata/dish_metadata_cafe1.csv
# Loaded 4768 rows from metadata
# Using columns: dish_id='dish_id', calories='total_calories'
# Loaded 4766 dishes with valid calorie data
# Loading images from: data/nutrition5k/imagery/realsense_overhead
# Found 2754 valid samples, skipped 1305
# Split 'val': 275 samples
# Loaded 4059 train IDs and 709 test IDs from split files
# Loading metadata from: data/nutrition5k/metadata/dish_metadata_cafe1.csv
# Loaded 4768 rows from metadata
# Using columns: dish_id='dish_id', calories='total_calories'
# Loaded 4766 dishes with valid calorie data
# Loading images from: data/nutrition5k/imagery/realsense_overhead
# Found 506 valid samples, skipped 203
# Split 'test': 506 samples
# Test samples: 506
#
# Loading trained regressor from artifacts/models/regressor_best.pth...
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100% 97.8M/97.8M [00:00<00:00, 140MB/s]
#
# Evaluating trained regressor...
# Evaluating regressor: 100% 16/16 [01:51<00:00,  6.99s/it]
# Evaluating mean baseline...
#
# ============================================================
# BASELINE COMPARISON RESULTS
# ============================================================
#
# Test set statistics:
#   Samples: 506
#   Mean calories: 256.0 kcal
#   Std calories: 211.9 kcal
#   Min calories: 1.1 kcal
#   Max calories: 1050.5 kcal
#
# 1. Mean Baseline (always predict 256.0 kcal):
#    MAE:  168.5 kcal
#    RMSE: 211.9 kcal
#    R²:   0.000
#    MAPE: 386.0%
#
# 2. Trained Regressor:
#    MAE:  107.5 kcal
#    RMSE: 150.8 kcal
#    R²:   0.493
#    MAPE: 168.2%
#
# ============================================================
# IMPROVEMENT OVER BASELINE
# ============================================================
#   MAE reduction: 60.9 kcal (36.2% improvement)
#   RMSE reduction: 61.1 kcal (28.8% improvement)
#   R² improvement: 0.493
# ============================================================
#
# Results saved to artifacts/baseline_regressor_results.json
# Comparison plot saved to artifacts/figures/regressor_baseline_comparison.png
# Scatter plot saved to artifacts/figures/regressor_scatter_comparison.png
#
# Done!
